# %%
import pandas as pd

# %%
df = pd.read_csv("employee.csv")
df

# %%
# display first 5 rows
df.head(10)

# %%
# display last 5 rows
df.tail(5)

# %%
#df.iloc[rows,columns]
df.iloc[10:20]

# %%
# display rows columns
df.shape

# %%
# display datatypes of each
df.dtypes

# %%
# select workclass from tablename
df['workclass']

# %%
df[['workclass','age']]

# %%
 # display all unique work classes
df['workclass'].unique()

# %%
#total count of unique work classes
df['workclass'].nunique()

# %%
df['workclass'].value_counts() # the occurence of each item

# %%
# select * from table where workclass = 'private' 
cond = df['workclass'] == " Private"
df[cond]

# %%
df[df['workclass'] == " Private"]
